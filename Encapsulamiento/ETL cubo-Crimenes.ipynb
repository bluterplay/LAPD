# %% [markdown]
# # ETL cubo

# %% [markdown]
# ## Preparación de ambiente

# %% [markdown]
# ### Carga de módulos

# %%
# Data Wrangling
import pandas as pd

# Conexión con GCP
from google.oauth2 import service_account

# Environment setup
pd.set_option("display.max_columns", 500)

# %% [markdown]
# ## Data Wrangling

# %%
df = pd.read_csv('./DatosLimpiosSuperclases.csv')
zonas=pd.read_csv('clusters.csv')

df=df.merge(zonas,left_on='dr_no',right_on='dr_no')
df.drop(columns=['zonas6'],axis=1,inplace=True)
df.rename(columns={'zonas5':'zonas'},inplace=True)

# %%
df
# Out:
#             dr_no   date_rptd    date_occ  time_occ  area rpt_dist_no  \
# 0        10304468  2020-01-08  2020-01-08      1350     3      Others
# 1       190101086  2020-01-02  2020-01-01       210     1      Others
# 2       200110444  2020-04-14  2020-02-13       720     1      Others
# 3       191501505  2020-01-01  2020-01-01      1050    15      Others
# 4       191921269  2020-01-01  2020-01-01       255    19      Others
# ...           ...         ...         ...       ...   ...         ...
# 673360  230405171  2023-02-05  2023-02-02      1110     4      Others
# 673361  231405429  2023-02-05  2023-02-05       770    14      Others
# 673362  231104474  2023-01-12  2023-01-12       760    11      Others
# 673363  230804266  2023-01-08  2023-01-08       630     8      Others
# 673364  231604807  2023-01-27  2023-01-26      1080    16      Others
#
#         part_1_2  crm_cd                             mocodes   vict_age  \
# 0              2     104                           0444 0913  36.000000
# 1              2     104                      0416 1822 1414  25.000000
# 2              2     100                                1501  23.127650
# 3              2     101                           0329 1402  76.000000
# 4              2     101                                0329  31.000000
# ...          ...     ...                                 ...        ...
# 673360         1     100  2000 1243 1241 0913 0400 0408 1814  41.000000
# 673361         1     103                           0325 0344  22.953462
# 673362         1     103                           1822 0344  42.000000
# 673363         1     103                           0344 1822  48.000000
# 673364         2     101                           1300 0329  23.000000
#
#        vict_sex vict_descent  premis_cd weapon_used_cd status      lat  \
# 0             F            B      501.0          400.0     AO  34.0141
# 1             M            H      102.0          500.0     IC  34.0459
# 2             X            X      726.0              0     AA  34.0448
# 3             F            W      502.0              0     IC  34.1685
# 4             X            X      409.0              0     IC  34.2198
# ...         ...          ...        ...            ...    ...      ...
# 673360        F            H      504.0          400.0     IC  34.0808
# 673361        X            X      402.0              0     IC  33.9846
# 673362        M            W      101.0              0     IC  34.1214
# 673363        M            O      717.0              0     IC  34.0611
# 673364        M            H      122.0              0     IC  34.2466
#
#              lon crm_cd_concat            ucr                   premis  zonas
# 0      -118.2978         624.0  SIMPLEASSAULT                 vivienda      0
# 1      -118.2545         624.0  SIMPLEASSAULT                    calle      0
# 2      -118.2474         845.0          Other                   Others      0
# 3      -118.4019    745.0998.0          Other                 vivienda      1
# 4      -118.4468         740.0          Other  establecimiento_publico      1
# ...          ...           ...            ...                      ...    ...
# 673360 -118.1738         236.0   AGG. Assults                 vivienda      0
# 673361 -118.4428         341.0    OTHER THEFT  establecimiento_publico      3
# 673362 -118.1915         440.0    OTHER THEFT                    calle      0
# 673363 -118.4184         341.0    OTHER THEFT               recreacion      3
# 673364 -118.4054         740.0          Other               transporte      1
#
# [673365 rows x 21 columns]

# %% [markdown]
# ### Dimensiones

# %%
crimens = pd.read_csv('crimecodes_Superclases (1).csv')

# %%
dicc_crim = dict(zip(crimens.NewCode, crimens.Superclass))

# %%
dicc_crim
# Out:
# {104: 'Robo Vehículo',
#  103: 'Robo',
#  102: 'Falta a la ley',
#  101: 'Disturbios a la sociedad',
#  100: 'Agresión'}

# %%
df.crm_cd = df.crm_cd.map(dicc_crim)

# %%
dicc_status = {'IC':'Investigation',
'AO':'Sanction',
'AA':'Arrest',
'JA':'Arrest',
'JO':'Sanction'}

# %%
df.status = df.status.map(dicc_status)
df.status.value_counts()
# Out:
# Investigation    538545
# Sanction          74127
# Arrest            60693
# Name: status, dtype: int64

# %%
#sé que dice disc de discretas pero necesitamos estas variables para el tablero gg
ls_disc = ["vict_sex", "zonas", "vict_descent", "premis",'lat','lon','crm_cd','vict_age','status']

# %% [markdown]
# ### Filtrado de datos

# %%
df = df[["date_occ"]+ls_disc].copy()

# %% [markdown]
# ### Corrección de tipo de dato

# %%
df.loc[:, "day"] = pd.to_datetime(df["date_occ"])
df.vict_age = df.vict_age.astype(str) 
df.zonas = df.zonas.astype(str) 
df.lat = df.lat.astype(str) 
df.lon = df.lon.astype(str) 
df.crm_cd = df.crm_cd.astype(str)

# %% [markdown]
# ### Reducción de cardinalidad

# %%
df = df[["day"]+ls_disc].groupby(["day"]+ls_disc, as_index=False).size()

# %% [markdown]
# ### Creación de dimensiones temporales

# %%
df["week"] = df["day"].dt.to_period('W').dt.start_time

# %%
df["month"] = df["day"].dt.to_period('M').dt.start_time

# %%
df["quarter"] = df["day"].dt.to_period('Q').dt.start_time

# %%
df["year"] = df["day"].dt.to_period('Y').dt.start_time

# %%
df
# Out:
#               day vict_sex zonas vict_descent                   premis  \
# 0      2020-01-01        F     0            A                   Others
# 1      2020-01-01        F     0            A                    calle
# 2      2020-01-01        F     0            A               recreacion
# 3      2020-01-01        F     0            A               recreacion
# 4      2020-01-01        F     0            B                   Others
# ...           ...      ...   ...          ...                      ...
# 668910 2023-02-27        X     4            U                    calle
# 668911 2023-02-27        X     4            U  establecimiento_publico
# 668912 2023-02-27        X     4            U  establecimiento_publico
# 668913 2023-02-27        X     4            U               recreacion
# 668914 2023-02-27        X     4            X  establecimiento_publico
#
#             lat        lon          crm_cd            vict_age         status  \
# 0       34.0487  -118.2627            Robo                22.0  Investigation
# 1       34.1294  -118.2326   Robo Vehículo                30.0  Investigation
# 2       34.0309  -118.2981   Robo Vehículo                25.0  Investigation
# 3          34.1  -118.3056   Robo Vehículo                62.0  Investigation
# 4       34.0099  -118.3089   Robo Vehículo                23.0  Investigation
# ...         ...        ...             ...                 ...            ...
# 668910  33.7739  -118.2678   Robo Vehículo  30.399084713340493  Investigation
# 668911  33.7926  -118.3043            Robo  31.818241907545133  Investigation
# 668912  33.9019  -118.2893            Robo   25.25929147708116  Investigation
# 668913  33.7547  -118.2927   Robo Vehículo  30.446868303197974  Investigation
# 668914  33.8315  -118.3065  Falta a la ley   24.51372396349512  Investigation
#
#         size       week      month    quarter       year
# 0          1 2019-12-30 2020-01-01 2020-01-01 2020-01-01
# 1          1 2019-12-30 2020-01-01 2020-01-01 2020-01-01
# 2          1 2019-12-30 2020-01-01 2020-01-01 2020-01-01
# 3          1 2019-12-30 2020-01-01 2020-01-01 2020-01-01
# 4          1 2019-12-30 2020-01-01 2020-01-01 2020-01-01
# ...      ...        ...        ...        ...        ...
# 668910     1 2023-02-27 2023-02-01 2023-01-01 2023-01-01
# 668911     1 2023-02-27 2023-02-01 2023-01-01 2023-01-01
# 668912     1 2023-02-27 2023-02-01 2023-01-01 2023-01-01
# 668913     1 2023-02-27 2023-02-01 2023-01-01 2023-01-01
# 668914     1 2023-02-27 2023-02-01 2023-01-01 2023-01-01
#
# [668915 rows x 15 columns]

# %%
df.isna().sum()
# Out:
# day             0
# vict_sex        0
# zonas           0
# vict_descent    0
# premis          0
# lat             0
# lon             0
# crm_cd          0
# vict_age        0
# status          0
# size            0
# week            0
# month           0
# quarter         0
# year            0
# dtype: int64

# %% [markdown]
# ## Preservación de cubo

# %% [markdown]
# ### Renombrado de columnas

# %%
df = df.rename(columns={"vict_sex": "gender", "zonas": "zone", "vict_descent": "descent", "premis": "place", "size": "crimes","crm_cd":"crime"})

# %%
df
# Out:
#               day gender zone descent                    place      lat  \
# 0      2020-01-01      F    0       A                   Others  34.0487
# 1      2020-01-01      F    0       A                    calle  34.1294
# 2      2020-01-01      F    0       A               recreacion  34.0309
# 3      2020-01-01      F    0       A               recreacion     34.1
# 4      2020-01-01      F    0       B                   Others  34.0099
# ...           ...    ...  ...     ...                      ...      ...
# 668910 2023-02-27      X    4       U                    calle  33.7739
# 668911 2023-02-27      X    4       U  establecimiento_publico  33.7926
# 668912 2023-02-27      X    4       U  establecimiento_publico  33.9019
# 668913 2023-02-27      X    4       U               recreacion  33.7547
# 668914 2023-02-27      X    4       X  establecimiento_publico  33.8315
#
#               lon           crime            vict_age         status  crimes  \
# 0       -118.2627            Robo                22.0  Investigation       1
# 1       -118.2326   Robo Vehículo                30.0  Investigation       1
# 2       -118.2981   Robo Vehículo                25.0  Investigation       1
# 3       -118.3056   Robo Vehículo                62.0  Investigation       1
# 4       -118.3089   Robo Vehículo                23.0  Investigation       1
# ...           ...             ...                 ...            ...     ...
# 668910  -118.2678   Robo Vehículo  30.399084713340493  Investigation       1
# 668911  -118.3043            Robo  31.818241907545133  Investigation       1
# 668912  -118.2893            Robo   25.25929147708116  Investigation       1
# 668913  -118.2927   Robo Vehículo  30.446868303197974  Investigation       1
# 668914  -118.3065  Falta a la ley   24.51372396349512  Investigation       1
#
#              week      month    quarter       year
# 0      2019-12-30 2020-01-01 2020-01-01 2020-01-01
# 1      2019-12-30 2020-01-01 2020-01-01 2020-01-01
# 2      2019-12-30 2020-01-01 2020-01-01 2020-01-01
# 3      2019-12-30 2020-01-01 2020-01-01 2020-01-01
# 4      2019-12-30 2020-01-01 2020-01-01 2020-01-01
# ...           ...        ...        ...        ...
# 668910 2023-02-27 2023-02-01 2023-01-01 2023-01-01
# 668911 2023-02-27 2023-02-01 2023-01-01 2023-01-01
# 668912 2023-02-27 2023-02-01 2023-01-01 2023-01-01
# 668913 2023-02-27 2023-02-01 2023-01-01 2023-01-01
# 668914 2023-02-27 2023-02-01 2023-01-01 2023-01-01
#
# [668915 rows x 15 columns]

# %% [markdown]
# ### Guardado de cubo

# %% [markdown]
# ### Lectura de credenciales BigQuery

# %% [markdown]
# credentials = service_account.Credentials.from_service_account_file(
#     './tscd-381619-8e1033c2f61b.json'
# )

# %% [markdown]
# ### Preservación de cubo

# %%
# pip install pandas_gbq
#df.to_gbq(destination_table="crimes.crimes_history", progress_bar=True, if_exists="replace", project_id="tscd-381619", credentials=credentials)

# %%
df

# %%
df.to_csv("crimes_cubo.csv")

# %%
df
# Out:
#               day gender zone descent                    place      lat  \
# 0      2020-01-01      F    0       A                   Others  34.0487
# 1      2020-01-01      F    0       A                    calle  34.1294
# 2      2020-01-01      F    0       A               recreacion  34.0309
# 3      2020-01-01      F    0       A               recreacion     34.1
# 4      2020-01-01      F    0       B                   Others  34.0099
# ...           ...    ...  ...     ...                      ...      ...
# 668910 2023-02-27      X    4       U                    calle  33.7739
# 668911 2023-02-27      X    4       U  establecimiento_publico  33.7926
# 668912 2023-02-27      X    4       U  establecimiento_publico  33.9019
# 668913 2023-02-27      X    4       U               recreacion  33.7547
# 668914 2023-02-27      X    4       X  establecimiento_publico  33.8315
#
#               lon           crime            vict_age         status  crimes  \
# 0       -118.2627            Robo                22.0  Investigation       1
# 1       -118.2326   Robo Vehículo                30.0  Investigation       1
# 2       -118.2981   Robo Vehículo                25.0  Investigation       1
# 3       -118.3056   Robo Vehículo                62.0  Investigation       1
# 4       -118.3089   Robo Vehículo                23.0  Investigation       1
# ...           ...             ...                 ...            ...     ...
# 668910  -118.2678   Robo Vehículo  30.399084713340493  Investigation       1
# 668911  -118.3043            Robo  31.818241907545133  Investigation       1
# 668912  -118.2893            Robo   25.25929147708116  Investigation       1
# 668913  -118.2927   Robo Vehículo  30.446868303197974  Investigation       1
# 668914  -118.3065  Falta a la ley   24.51372396349512  Investigation       1
#
#              week      month    quarter       year
# 0      2019-12-30 2020-01-01 2020-01-01 2020-01-01
# 1      2019-12-30 2020-01-01 2020-01-01 2020-01-01
# 2      2019-12-30 2020-01-01 2020-01-01 2020-01-01
# 3      2019-12-30 2020-01-01 2020-01-01 2020-01-01
# 4      2019-12-30 2020-01-01 2020-01-01 2020-01-01
# ...           ...        ...        ...        ...
# 668910 2023-02-27 2023-02-01 2023-01-01 2023-01-01
# 668911 2023-02-27 2023-02-01 2023-01-01 2023-01-01
# 668912 2023-02-27 2023-02-01 2023-01-01 2023-01-01
# 668913 2023-02-27 2023-02-01 2023-01-01 2023-01-01
# 668914 2023-02-27 2023-02-01 2023-01-01 2023-01-01
#
# [668915 rows x 15 columns]
