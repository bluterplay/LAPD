# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("./lapd.csv")

# %% [markdown]
# # Pie Chart

# %%
palette_color = sns.color_palette('pastel')
area = df.groupby(["area_name"])["area_name"].count()[:5]
plt.pie(area,labels=area.index, colors=palette_color, autopct='%.0f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x7f4584d90bb0>,
#   <matplotlib.patches.Wedge at 0x7f4584d9f340>,
#   <matplotlib.patches.Wedge at 0x7f4584d9fa60>,
#   <matplotlib.patches.Wedge at 0x7f4584dad0a0>,
#   <matplotlib.patches.Wedge at 0x7f4584dad7c0>],
#  [Text(1.099366399158716, 0.03732988616107412, '77th Street'),
#   Text(-1.0971771179665726, 0.07875513831214957, 'Central'),
#   Text(1.0805004617010756, -0.2062007571852307, 'Devonshire'),
#   Text(1.0881227059597158, -0.16121096977224028, 'Foothill'),
#   Text(1.097739944284022, -0.07047705104012313, 'Harbor')],
#  [Text(0.5996543995411178, 0.020361756087858607, '1%'),
#   Text(-0.598460246163585, 0.0429573481702634, '96%'),
#   Text(0.5893638882005866, -0.1124731402828531, '1%'),
#   Text(0.5935214759780267, -0.08793325623940379, '1%'),
#   Text(0.5987672423367393, -0.03844202784006715, '2%')])

# %%
palette_color = sns.color_palette('pastel')
area = df.groupby(["crm_cd_desc"])["crm_cd_desc"].count()[:5]
plt.pie(area,labels=area.index, colors=palette_color, autopct='%.0f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x7f4584cf5550>,
#   <matplotlib.patches.Wedge at 0x7f4584cf5c10>,
#   <matplotlib.patches.Wedge at 0x7f4584d04310>,
#   <matplotlib.patches.Wedge at 0x7f4584d04a30>,
#   <matplotlib.patches.Wedge at 0x7f4584d12190>],
#  [Text(1.0984756012113208, 0.057890876167385696, 'ARSON'),
#   Text(0.7176903284632028, 0.8336189731708247, 'ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT'),
#   Text(-0.22051329307472053, 1.0776705839807184, 'ATTEMPTED ROBBERY'),
#   Text(-0.6879928148304398, -0.8582924249588181, 'BATTERY - SIMPLE ASSAULT'),
#   Text(1.0972904577429428, -0.07715990763526813, 'BATTERY POLICE (SIMPLE)')],
#  [Text(0.5991685097516294, 0.031576841545846744, '2%'),
#   Text(0.3914674518890197, 0.454701258093177, '24%'),
#   Text(-0.12027997804075664, 0.5878203185349372, '5%'),
#   Text(-0.3752688080893308, -0.4681595045229916, '67%'),
#   Text(0.5985220678597869, -0.042087222346509884, '2%')])

# %%
palette_color = sns.color_palette('pastel')
area = df.groupby(["vict_sex"])["vict_sex"].count()[:5]
plt.pie(area,labels=area.index, colors=palette_color, autopct='%.0f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x7f4584b91c40>,
#   <matplotlib.patches.Wedge at 0x7f4584b9f310>,
#   <matplotlib.patches.Wedge at 0x7f4584b9fa30>],
#  [Text(0.401711640233886, 1.0240252721982017, 'F'),
#   Text(-0.6258048115927242, -0.9046371304492178, 'M'),
#   Text(1.0706948737091195, -0.2522151609499571, 'X')],
#  [Text(0.21911544012757417, 0.5585592393808372, '38%'),
#   Text(-0.3413480790505768, -0.4934384347904824, '55%'),
#   Text(0.5840153856595197, -0.13757190597270386, '7%')])

# %%
palette_color = sns.color_palette('pastel')
area = df.groupby(["weapon_desc"])["weapon_desc"].count()[:5]
plt.pie(area,labels=area.index, colors=palette_color, autopct='%.0f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x7f4584b6a490>,
#   <matplotlib.patches.Wedge at 0x7f4584b6aa30>,
#   <matplotlib.patches.Wedge at 0x7f4584af7190>,
#   <matplotlib.patches.Wedge at 0x7f4584af78b0>,
#   <matplotlib.patches.Wedge at 0x7f4584af7fd0>],
#  [Text(0.33991867422268784, 1.0461621742897658, 'BLUNT INSTRUMENT'),
#   Text(-1.0461621822461362, 0.3399186497354952, 'BOMB THREAT'),
#   Text(-0.6465637025335373, -0.8899187482945414, 'BOTTLE'),
#   Text(0.646563890003987, -0.8899186120892812, 'CLUB/BAT'),
#   Text(1.0461622140716127, -0.3399185517867209, 'DEMAND NOTE')],
#  [Text(0.1854101859396479, 0.5706339132489631, '40%'),
#   Text(-0.5706339175888016, 0.18541017258299736, '10%'),
#   Text(-0.35267111047283856, -0.4854102263424771, '30%'),
#   Text(0.3526712127294474, -0.48541015204869875, '10%'),
#   Text(0.5706339349481523, -0.18541011915639322, '10%')])

# %%
palette_color = sns.color_palette('pastel')
area = df.groupby(["premis_desc"])["premis_desc"].count()[:5]
plt.pie(area,labels=area.index, colors=palette_color, autopct='%.0f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x7f4584abdd60>,
#   <matplotlib.patches.Wedge at 0x7f4584acb3a0>,
#   <matplotlib.patches.Wedge at 0x7f4584acbac0>,
#   <matplotlib.patches.Wedge at 0x7f4584ad8220>,
#   <matplotlib.patches.Wedge at 0x7f4584ad8940>],
#  [Text(1.068035996798755, 0.26324724033138536, '7TH AND METRO CENTER (NOT LINE SPECIFIC)'),
#   Text(0.823361803287838, 0.7294349463019987, 'ABANDONED BUILDING ABANDONED HOUSE'),
#   Text(-0.8233618545088073, 0.7294348884854754, 'ALLEY'),
#   Text(-0.6248711676151324, -0.9052822896109818, 'AMTRAK TRAIN'),
#   Text(0.6248713159427525, -0.905282187227813, 'BANK')],
#  [Text(0.5825650891629571, 0.14358940381711927, '8%'),
#   Text(0.4491064381570025, 0.3978736070738174, '8%'),
#   Text(-0.44910646609571303, 0.397873575537532, '46%'),
#   Text(-0.34083881869916305, -0.4937903397878082, '8%'),
#   Text(0.34083889960513764, -0.4937902839424434, '31%')])

# %% [markdown]
# # Construcción de tabla de frecuencias

# %%
pd.DataFrame(df["area_name"].value_counts())[:5]
# Out:
#             area_name
# Central           796
# West LA            20
# Hollywood          17
# Harbor             17
# Hollenbeck         16

# %%
pd.DataFrame(df["premis_desc"].value_counts())[:5]
# Out:
#                                               premis_desc
# STREET                                                215
# SIDEWALK                                              129
# MULTI-UNIT DWELLING (APARTMENT, DUPLEX, ETC)          108
# PARKING LOT                                            73
# SINGLE FAMILY DWELLING                                 69

# %%
pd.DataFrame(df["weapon_desc"].value_counts())[:5]
# Out:
#                                                 weapon_desc
# STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)          226
# UNKNOWN WEAPON/OTHER WEAPON                              64
# VERBAL THREAT                                            17
# HAND GUN                                                 11
# OTHER KNIFE                                              11

# %%
pd.DataFrame(df["vict_sex"].value_counts())[:5]
# Out:
#    vict_sex
# M       511
# F       357
# X        69

# %%
pd.DataFrame(df["crm_cd_desc"].value_counts())[:5]
# Out:
#                                                     crm_cd_desc
# BURGLARY FROM VEHICLE                                       127
# BATTERY - SIMPLE ASSAULT                                    120
# THEFT PLAIN - PETTY ($950 & UNDER)                           76
# VANDALISM - FELONY ($400 & OVER, ALL CHURCH VAN...           53
# SHOPLIFTING - PETTY THEFT ($950 & UNDER)                     50

# %% [markdown]
# # Gráfico de barras

# %%
sns.countplot(x=df["area_name"])
# Out:
# <AxesSubplot:xlabel='area_name', ylabel='count'>

# %%
c = sns.countplot(x=df["crm_cd_desc"])
c.set_xticklabels(c.get_xticklabels(), rotation=45, horizontalalignment="right")
# Out:
# [Text(0, 0, 'BATTERY - SIMPLE ASSAULT'),
#  Text(1, 0, 'SEX OFFENDER REGISTRANT OUT OF COMPLIANCE'),
#  Text(2, 0, 'VANDALISM - MISDEAMEANOR ($399 OR UNDER)'),
#  Text(3, 0, 'VANDALISM - FELONY ($400 & OVER, ALL CHURCH VANDALISMS)'),
#  Text(4, 0, 'RAPE, FORCIBLE'),
#  Text(5, 0, 'SHOPLIFTING - PETTY THEFT ($950 & UNDER)'),
#  Text(6, 0, 'OTHER MISCELLANEOUS CRIME'),
#  Text(7, 0, 'THEFT-GRAND ($950.01 & OVER)EXCPT,GUNS,FOWL,LIVESTK,PROD'),
#  Text(8, 0, 'BURGLARY FROM VEHICLE'),
#  Text(9, 0, 'CRIMINAL THREATS - NO WEAPON DISPLAYED'),
#  Text(10, 0, 'ARSON'),
#  Text(11, 0, 'INTIMATE PARTNER - SIMPLE ASSAULT'),
#  Text(12, 0, 'THEFT PLAIN - PETTY ($950 & UNDER)'),
#  Text(13, 0, 'THEFT OF IDENTITY'),
#  Text(14, 0, 'ROBBERY'),
#  Text(15, 0, 'ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT'),
#  Text(16, 0, 'BURGLARY'),
#  Text(17, 0, 'VEHICLE - STOLEN'),
#  Text(18, 0, 'THEFT FROM MOTOR VEHICLE - PETTY ($950 & UNDER)'),
#  Text(19, 0, 'BRANDISH WEAPON'),
#  Text(20, 0, 'INTIMATE PARTNER - AGGRAVATED ASSAULT'),
#  Text(21, 0, 'BUNCO, GRAND THEFT'),
#  Text(22, 0, 'THEFT, PERSON'),
#  Text(23, 0, 'BATTERY WITH SEXUAL CONTACT'),
#  Text(24, 0, 'BIKE - STOLEN'),
#  Text(25, 0, 'BATTERY POLICE (SIMPLE)'),
#  Text(26, 0, 'LETTERS, LEWD  -  TELEPHONE CALLS, LEWD'),
#  Text(27, 0, 'VIOLATION OF COURT ORDER'),
#  Text(28, 0, 'TRESPASSING'),
#  Text(29, 0, 'THEFT FROM MOTOR VEHICLE - GRAND ($950.01 AND OVER)'),
#  Text(30, 0, 'VIOLATION OF RESTRAINING ORDER'),
#  Text(31, 0, 'DISTURBING THE PEACE'),
#  Text(32, 0, 'THEFT FROM MOTOR VEHICLE - ATTEMPT'),
#  Text(33, 0, 'THROWING OBJECT AT MOVING VEHICLE'),
#  Text(34, 0, 'EXTORTION'),
#  Text(35, 0, 'SEX,UNLAWFUL(INC MUTUAL CONSENT, PENETRATION W/ FRGN OBJ'),
#  Text(36, 0, 'CHILD STEALING'),
#  Text(37, 0, 'CRM AGNST CHLD (13 OR UNDER) (14-15 & SUSP 10 YRS OLDER)'),
#  Text(38, 0, 'ATTEMPTED ROBBERY'),
#  Text(39, 0, 'OTHER ASSAULT'),
#  Text(40, 0, 'BOMB SCARE'),
#  Text(41, 0, 'DOCUMENT FORGERY / STOLEN FELONY'),
#  Text(42, 0, 'SEXUAL PENETRATION W/FOREIGN OBJECT'),
#  Text(43, 0, 'SHOTS FIRED AT INHABITED DWELLING'),
#  Text(44, 0, 'BURGLARY, ATTEMPTED'),
#  Text(45, 0, 'FAILURE TO YIELD'),
#  Text(46, 0, 'INDECENT EXPOSURE'),
#  Text(47, 0, 'ORAL COPULATION'),
#  Text(48, 0, 'EMBEZZLEMENT, GRAND THEFT ($950.01 & OVER)'),
#  Text(49, 0, 'VIOLATION OF TEMPORARY RESTRAINING ORDER'),
#  Text(50, 0, 'BUNCO, PETTY THEFT'),
#  Text(51, 0, 'KIDNAPPING - GRAND ATTEMPT'),
#  Text(52, 0, 'SHOPLIFTING-GRAND THEFT ($950.01 & OVER)'),
#  Text(53, 0, 'RESISTING ARREST'),
#  Text(54, 0, 'DISCHARGE FIREARMS/SHOTS FIRED'),
#  Text(55, 0, 'THREATENING PHONE CALLS/LETTERS'),
#  Text(56, 0, 'KIDNAPPING'),
#  Text(57, 0, 'LEWD/LASCIVIOUS ACTS WITH CHILD'),
#  Text(58, 0, 'LEWD CONDUCT'),
#  Text(59, 0, 'UNAUTHORIZED COMPUTER ACCESS'),
#  Text(60, 0, 'PURSE SNATCHING'),
#  Text(61, 0, 'SODOMY/SEXUAL CONTACT B/W PENIS OF ONE PERS TO ANUS OTH'),
#  Text(62, 0, 'CHILD NEGLECT (SEE 300 W.I.C.)'),
#  Text(63, 0, 'CONTEMPT OF COURT')]

# %%
sns.countplot(x=df["vict_sex"])
# Out:
# <AxesSubplot:xlabel='vict_sex', ylabel='count'>

# %%
sns.countplot(x=df["premis_desc"])
# Out:
# <AxesSubplot:xlabel='premis_desc', ylabel='count'>

# %%
sns.countplot(x=df["weapon_desc"])
# Out:
# <AxesSubplot:xlabel='weapon_desc', ylabel='count'>

# %% [markdown]
# # A lo largo del tiempo

# %%
df["date_rptd"]
# Out:
# 0      2020-01-08
# 1      2020-01-02
# 2      2020-04-14
# 3      2020-01-01
# 4      2020-01-01
#           ...
# 994    2020-01-28
# 995    2020-01-29
# 996    2020-01-29
# 997    2020-01-29
# 998    2020-01-29
# Name: date_rptd, Length: 999, dtype: object

# %%
time_series = df.groupby(["date_rptd"])["crm_cd_desc"].count()

# %%
sns.set_theme(style="darkgrid")

sns.lineplot(x=time_series.index, y=time_series.values,
             data=time_series)
# Out:
# <AxesSubplot:xlabel='date_rptd'>
